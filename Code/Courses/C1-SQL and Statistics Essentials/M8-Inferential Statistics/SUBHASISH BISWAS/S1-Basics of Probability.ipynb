# %%
from SUBHASISH import *

# %%
ShowImage("CleanShot 2025-03-01 at 15.24.15@2x.png")

# %%
ShowImage("CleanShot 2025-03-01 at 15.26.20@2x.png")

# %% [markdown]
# [Statistical Inference for Data Science ](https://leanpub.com/LittleInferenceBook)
#
# [Seeing Theory](https://seeing-theory.brown.edu/)
#
# [Royce Fellowship Program](https://www.brown.edu/academics/college/fellowships/royce/)
#
# [Tricha Anjali](https://www.linkedin.com/in/tricha-anjali/)

# %%
ShowImage("CleanShot 2025-03-01 at 15.35.04@2x.png")

# %%
ShowImage("CleanShot 2025-03-01 at 15.53.54@2x.png")

# %%
ShowImage("CleanShot 2025-03-01 at 15.59.44@2x.png")
